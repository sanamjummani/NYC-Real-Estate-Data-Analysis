# %% [markdown]
# # CLEANING DATA

# %% [markdown]
# IMPORTING LIBRARIES:

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# SETTING PANDAS NUMERIC VIEWING  SETTINGS AND IMPORTING CSV INTO DATAFRAME:

# %%
pd.set_option('display.float_format', '{:,.2f}'.format)

# %%
df = pd.read_csv('/Users/sanajummani/Desktop/RE project pandas/nyc-rolling-sales.csv')

# %% [markdown]
# INSPECTING/READING DATA:

# %%
df.shape
# Out:
# (84548, 22)

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'BOROUGH', 'NEIGHBORHOOD', 'BUILDING CLASS CATEGORY',
#        'TAX CLASS AT PRESENT', 'BLOCK', 'LOT', 'EASE-MENT',
#        'BUILDING CLASS AT PRESENT', 'ADDRESS', 'APARTMENT NUMBER', 'ZIP CODE',
#        'RESIDENTIAL UNITS', 'COMMERCIAL UNITS', 'TOTAL UNITS',
#        'LAND SQUARE FEET', 'GROSS SQUARE FEET', 'YEAR BUILT',
#        'TAX CLASS AT TIME OF SALE', 'BUILDING CLASS AT TIME OF SALE',
#        'SALE PRICE', 'SALE DATE'],
#       dtype='object')

# %%
df.head()
# Out:
#    Unnamed: 0  BOROUGH   NEIGHBORHOOD  \
# 0           4        1  ALPHABET CITY
# 1           5        1  ALPHABET CITY
# 2           6        1  ALPHABET CITY
# 3           7        1  ALPHABET CITY
# 4           8        1  ALPHABET CITY
#
#                        BUILDING CLASS CATEGORY TAX CLASS AT PRESENT  BLOCK  \
# 0  07 RENTALS - WALKUP APARTMENTS                                2A    392
# 1  07 RENTALS - WALKUP APARTMENTS                                 2    399
# 2  07 RENTALS - WALKUP APARTMENTS                                 2    399
# 3  07 RENTALS - WALKUP APARTMENTS                                2B    402
# 4  07 RENTALS - WALKUP APARTMENTS                                2A    404
#
#    LOT EASE-MENT BUILDING CLASS AT PRESENT                 ADDRESS  ...  \
# 0    6                                  C2            153 AVENUE B  ...
# 1   26                                  C7   234 EAST 4TH   STREET  ...
# ...

# %% [markdown]
# DROPPING UNNECESSARY COLUMN:

# %%
df = df.drop(columns = 'Unnamed: 0')

# %%
df.head()
# Out:
#    BOROUGH   NEIGHBORHOOD                      BUILDING CLASS CATEGORY  \
# 0        1  ALPHABET CITY  07 RENTALS - WALKUP APARTMENTS
# 1        1  ALPHABET CITY  07 RENTALS - WALKUP APARTMENTS
# 2        1  ALPHABET CITY  07 RENTALS - WALKUP APARTMENTS
# 3        1  ALPHABET CITY  07 RENTALS - WALKUP APARTMENTS
# 4        1  ALPHABET CITY  07 RENTALS - WALKUP APARTMENTS
#
#   TAX CLASS AT PRESENT  BLOCK  LOT EASE-MENT BUILDING CLASS AT PRESENT  \
# 0                   2A    392    6                                  C2
# 1                    2    399   26                                  C7
# 2                    2    399   39                                  C7
# 3                   2B    402   21                                  C4
# 4                   2A    404   55                                  C2
#
#                   ADDRESS APARTMENT NUMBER  ...  RESIDENTIAL UNITS  \
# 0            153 AVENUE B                   ...                  5
# ...

# %%
df
# Out:
#        BOROUGH   NEIGHBORHOOD                      BUILDING CLASS CATEGORY  \
# 0            1  ALPHABET CITY  07 RENTALS - WALKUP APARTMENTS
# 1            1  ALPHABET CITY  07 RENTALS - WALKUP APARTMENTS
# 2            1  ALPHABET CITY  07 RENTALS - WALKUP APARTMENTS
# 3            1  ALPHABET CITY  07 RENTALS - WALKUP APARTMENTS
# 4            1  ALPHABET CITY  07 RENTALS - WALKUP APARTMENTS
# ...        ...            ...                                          ...
# 84543        5        WOODROW  02 TWO FAMILY DWELLINGS
# 84544        5        WOODROW  02 TWO FAMILY DWELLINGS
# 84545        5        WOODROW  02 TWO FAMILY DWELLINGS
# 84546        5        WOODROW  22 STORE BUILDINGS
# 84547        5        WOODROW  35 INDOOR PUBLIC AND CULTURAL FACILITIES
#
#       TAX CLASS AT PRESENT  BLOCK  LOT EASE-MENT BUILDING CLASS AT PRESENT  \
# 0                       2A    392    6                                  C2
# ...

# %% [markdown]
# CHECKING NULL VALUES:

# %%
df.isnull().sum()
# Out:
# BOROUGH                           0
# NEIGHBORHOOD                      0
# BUILDING CLASS CATEGORY           0
# TAX CLASS AT PRESENT              0
# BLOCK                             0
# LOT                               0
# EASE-MENT                         0
# BUILDING CLASS AT PRESENT         0
# ADDRESS                           0
# APARTMENT NUMBER                  0
# ZIP CODE                          0
# RESIDENTIAL UNITS                 0
# COMMERCIAL UNITS                  0
# TOTAL UNITS                       0
# LAND SQUARE FEET                  0
# GROSS SQUARE FEET                 0
# YEAR BUILT                        0
# TAX CLASS AT TIME OF SALE         0
# BUILDING CLASS AT TIME OF SALE    0
# SALE PRICE                        0
# SALE DATE                         0
# dtype: int64

# %% [markdown]
# SINCE WE RECEIVED ZERO NULL VALUES- TO FIND WHATS WRONG AND IN WHICH WAY IS IT RECORDED?

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 84548 entries, 0 to 84547
# Data columns (total 21 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   BOROUGH                         84548 non-null  int64
#  1   NEIGHBORHOOD                    84548 non-null  object
#  2   BUILDING CLASS CATEGORY         84548 non-null  object
#  3   TAX CLASS AT PRESENT            84548 non-null  object
#  4   BLOCK                           84548 non-null  int64
#  5   LOT                             84548 non-null  int64
#  6   EASE-MENT                       84548 non-null  object
#  7   BUILDING CLASS AT PRESENT       84548 non-null  object
#  8   ADDRESS                         84548 non-null  object
#  9   APARTMENT NUMBER                84548 non-null  object
#  10  ZIP CODE                        84548 non-null  int64
#  11  RESIDENTIAL UNITS               84548 non-null  int64
# ...

# %% [markdown]
# FOUND THAT MAJORITY MISSING VALUES ARE RECORDED IN TWO WAYS: " ", " - "

# %%
df[df['SALE PRICE'] == ' -  '].count()
# Out:
# BOROUGH                           14561
# NEIGHBORHOOD                      14561
# BUILDING CLASS CATEGORY           14561
# TAX CLASS AT PRESENT              14561
# BLOCK                             14561
# LOT                               14561
# EASE-MENT                         14561
# BUILDING CLASS AT PRESENT         14561
# ADDRESS                           14561
# APARTMENT NUMBER                  14561
# ZIP CODE                          14561
# RESIDENTIAL UNITS                 14561
# COMMERCIAL UNITS                  14561
# TOTAL UNITS                       14561
# LAND SQUARE FEET                  14561
# GROSS SQUARE FEET                 14561
# YEAR BUILT                        14561
# TAX CLASS AT TIME OF SALE         14561
# BUILDING CLASS AT TIME OF SALE    14561
# SALE PRICE                        14561
# SALE DATE                         14561
# dtype: int64

# %% [markdown]
# TRYING TO INSPECT DATA STATS:

# %%
df.describe()
# Out:
#         BOROUGH     BLOCK       LOT  ZIP CODE  RESIDENTIAL UNITS  \
# count 84,548.00 84,548.00 84,548.00 84,548.00          84,548.00
# mean       3.00  4,237.22    376.22 10,731.99               2.03
# std        1.29  3,568.26    658.14  1,290.88              16.72
# min        1.00      1.00      1.00      0.00               0.00
# 25%        2.00  1,322.75     22.00 10,305.00               0.00
# 50%        3.00  3,311.00     50.00 11,209.00               1.00
# 75%        4.00  6,281.00  1,001.00 11,357.00               2.00
# max        5.00 16,322.00  9,106.00 11,694.00           1,844.00
#
#        COMMERCIAL UNITS  TOTAL UNITS  YEAR BUILT  TAX CLASS AT TIME OF SALE
# count         84,548.00    84,548.00   84,548.00                  84,548.00
# mean               0.19         2.25    1,789.32                       1.66
# std                8.71        18.97      537.34                       0.82
# min                0.00         0.00        0.00                       1.00
# ...

# %% [markdown]
# DROPPING UNNECESSARY COLUMN:

# %%
df = df.drop(columns = ['EASE-MENT'])

# %% [markdown]
# INSPECTING PRICE COLUMNS AND MISSING VALUES HERE:

# %%
df['SALE PRICE'].isna().sum()
# Out:
# 0

# %%
df['SALE PRICE'].dtype
# Out:
# dtype('O')

# %%
df['SALE PRICE'].apply(lambda x: str(x).count("-")).sum()
# Out:
# 14561

# %%
df['SALE PRICE'].apply(lambda x: str(x).count(" ")).sum()
# Out:
# 43683

# %%
df.applymap(lambda x: str(x).count("-")).sum()
# Out:
# BOROUGH                                0
# NEIGHBORHOOD                       19371
# BUILDING CLASS CATEGORY            38292
# TAX CLASS AT PRESENT                   0
# BLOCK                                  0
# LOT                                    0
# BUILDING CLASS AT PRESENT              0
# ADDRESS                            25141
# APARTMENT NUMBER                     808
# ZIP CODE                               0
# RESIDENTIAL UNITS                      0
# COMMERCIAL UNITS                       0
# TOTAL UNITS                            0
# LAND SQUARE FEET                   26252
# GROSS SQUARE FEET                  27612
# YEAR BUILT                             0
# TAX CLASS AT TIME OF SALE              0
# BUILDING CLASS AT TIME OF SALE         0
# SALE PRICE                         14561
# SALE DATE                         169096
# dtype: int64

# %%
df.applymap(lambda x: str(x).count(" ")).sum()
# Out:
# BOROUGH                                 0
# NEIGHBORHOOD                        67350
# BUILDING CLASS CATEGORY           1746496
# TAX CLASS AT PRESENT                  738
# BLOCK                                   0
# LOT                                     0
# BUILDING CLASS AT PRESENT             738
# ADDRESS                            236125
# APARTMENT NUMBER                    65703
# ZIP CODE                                0
# RESIDENTIAL UNITS                       0
# COMMERCIAL UNITS                        0
# TOTAL UNITS                             0
# LAND SQUARE FEET                    78756
# GROSS SQUARE FEET                   82836
# YEAR BUILT                              0
# TAX CLASS AT TIME OF SALE               0
# BUILDING CLASS AT TIME OF SALE          0
# SALE PRICE                          43683
# SALE DATE                           84548
# dtype: int64

# %%
df.shape
# Out:
# (84548, 20)

# %%
df.duplicated().sum()
# Out:
# 765

# %% [markdown]
# REMOVING DUPLICATED ROWS:

# %%
df = df.drop_duplicates()

# %% [markdown]
# REPLACING MISSING VALUES WITH "NAN" TO KEEP TRACK OF NULL VALUES:

# %%
df = df.replace({'-':np.nan, ' ':np.nan})

# %%
df.isnull().sum()
# Out:
# BOROUGH                               0
# NEIGHBORHOOD                          0
# BUILDING CLASS CATEGORY               0
# TAX CLASS AT PRESENT                738
# BLOCK                                 0
# LOT                                   0
# BUILDING CLASS AT PRESENT           738
# ADDRESS                               0
# APARTMENT NUMBER                  64934
# ZIP CODE                              0
# RESIDENTIAL UNITS                     0
# COMMERCIAL UNITS                      0
# TOTAL UNITS                           0
# LAND SQUARE FEET                      0
# GROSS SQUARE FEET                     0
# YEAR BUILT                            0
# TAX CLASS AT TIME OF SALE             0
# BUILDING CLASS AT TIME OF SALE        0
# SALE PRICE                            0
# SALE DATE                             0
# dtype: int64

# %%
df.head()
# Out:
#    BOROUGH   NEIGHBORHOOD                      BUILDING CLASS CATEGORY  \
# 0        1  ALPHABET CITY  07 RENTALS - WALKUP APARTMENTS
# 1        1  ALPHABET CITY  07 RENTALS - WALKUP APARTMENTS
# 2        1  ALPHABET CITY  07 RENTALS - WALKUP APARTMENTS
# 3        1  ALPHABET CITY  07 RENTALS - WALKUP APARTMENTS
# 4        1  ALPHABET CITY  07 RENTALS - WALKUP APARTMENTS
#
#   TAX CLASS AT PRESENT  BLOCK  LOT BUILDING CLASS AT PRESENT  \
# 0                   2A    392    6                        C2
# 1                    2    399   26                        C7
# 2                    2    399   39                        C7
# 3                   2B    402   21                        C4
# 4                   2A    404   55                        C2
#
#                   ADDRESS APARTMENT NUMBER  ZIP CODE  RESIDENTIAL UNITS  \
# 0            153 AVENUE B              NaN     10009                  5
# 1   234 EAST 4TH   STREET              NaN     10009                 28
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 83783 entries, 0 to 84547
# Data columns (total 20 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   BOROUGH                         83783 non-null  int64
#  1   NEIGHBORHOOD                    83783 non-null  object
#  2   BUILDING CLASS CATEGORY         83783 non-null  object
#  3   TAX CLASS AT PRESENT            83045 non-null  object
#  4   BLOCK                           83783 non-null  int64
#  5   LOT                             83783 non-null  int64
#  6   BUILDING CLASS AT PRESENT       83045 non-null  object
#  7   ADDRESS                         83783 non-null  object
#  8   APARTMENT NUMBER                18849 non-null  object
#  9   ZIP CODE                        83783 non-null  int64
#  10  RESIDENTIAL UNITS               83783 non-null  int64
#  11  COMMERCIAL UNITS                83783 non-null  int64
# ...

# %% [markdown]
# CORRECTING DATA TYPES FOR NUMERICAL FIELD COLUMNS:

# %%
numeric_columns = ['LAND SQUARE FEET', 'GROSS SQUARE FEET', 'SALE PRICE']

# %%
for col in df.columns:
    if col in numeric_columns:
        df[col] = pd.to_numeric(df[col], errors='coerce')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 83783 entries, 0 to 84547
# Data columns (total 20 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   BOROUGH                         83783 non-null  int64
#  1   NEIGHBORHOOD                    83783 non-null  object
#  2   BUILDING CLASS CATEGORY         83783 non-null  object
#  3   TAX CLASS AT PRESENT            83045 non-null  object
#  4   BLOCK                           83783 non-null  int64
#  5   LOT                             83783 non-null  int64
#  6   BUILDING CLASS AT PRESENT       83045 non-null  object
#  7   ADDRESS                         83783 non-null  object
#  8   APARTMENT NUMBER                18849 non-null  object
#  9   ZIP CODE                        83783 non-null  int64
#  10  RESIDENTIAL UNITS               83783 non-null  int64
#  11  COMMERCIAL UNITS                83783 non-null  int64
# ...

# %%
pd.set_option('display.max_rows', 200)

# %%
df
# Out:
#        BOROUGH   NEIGHBORHOOD                      BUILDING CLASS CATEGORY  \
# 0            1  ALPHABET CITY  07 RENTALS - WALKUP APARTMENTS
# 1            1  ALPHABET CITY  07 RENTALS - WALKUP APARTMENTS
# 2            1  ALPHABET CITY  07 RENTALS - WALKUP APARTMENTS
# 3            1  ALPHABET CITY  07 RENTALS - WALKUP APARTMENTS
# 4            1  ALPHABET CITY  07 RENTALS - WALKUP APARTMENTS
# ...        ...            ...                                          ...
# 84543        5        WOODROW  02 TWO FAMILY DWELLINGS
# 84544        5        WOODROW  02 TWO FAMILY DWELLINGS
# 84545        5        WOODROW  02 TWO FAMILY DWELLINGS
# 84546        5        WOODROW  22 STORE BUILDINGS
# 84547        5        WOODROW  35 INDOOR PUBLIC AND CULTURAL FACILITIES
#
#       TAX CLASS AT PRESENT  BLOCK  LOT BUILDING CLASS AT PRESENT  \
# 0                       2A    392    6                        C2
# 1                        2    399   26                        C7
# ...

# %% [markdown]
# RUNNING REPLACEMENT OF CHARACTERS AND BLANKS TO "NAN" AGAIN TO REFLECT ON NUMERICAL COLUMNS NOW:

# %%
df = df.replace({'-':np.nan, ' ':np.nan})

# %%
df['LAND SQUARE FEET'] = df['LAND SQUARE FEET'].replace({0:np.nan})

# %%
df['GROSS SQUARE FEET'] = df['GROSS SQUARE FEET'].replace({0:np.nan})

# %%
df.isnull().sum()
# Out:
# BOROUGH                               0
# NEIGHBORHOOD                          0
# BUILDING CLASS CATEGORY               0
# TAX CLASS AT PRESENT                738
# BLOCK                                 0
# LOT                                   0
# BUILDING CLASS AT PRESENT           738
# ADDRESS                               0
# APARTMENT NUMBER                  64934
# ZIP CODE                              0
# RESIDENTIAL UNITS                     0
# COMMERCIAL UNITS                      0
# TOTAL UNITS                           0
# LAND SQUARE FEET                  36351
# GROSS SQUARE FEET                 38745
# YEAR BUILT                            0
# TAX CLASS AT TIME OF SALE             0
# BUILDING CLASS AT TIME OF SALE        0
# SALE PRICE                        14176
# SALE DATE                             0
# dtype: int64

# %%
df.shape
# Out:
# (83783, 20)

# %% [markdown]
# DROPPING NULL ROWS OF SALE PRICE COLUMN AS THOSE VALUES CANT BE FILLED OR ESTIMATED:

# %%
df = df.dropna(subset = "SALE PRICE")

# %% [markdown]
# REPLACING SIZE COLUMNS WITH MEDIAN VALUES (BECAUSE DATA ISNT EVENLY DISTRIBUTED AND MANY OUTLIERS) TO REPLACE NULL:

# %%
 df["LAND SQUARE FEET"] = df["LAND SQUARE FEET"].fillna(df["LAND SQUARE FEET"].median())
 df["GROSS SQUARE FEET"] = df["GROSS SQUARE FEET"].fillna(df["GROSS SQUARE FEET"].median())

# %%
df["LAND SQUARE FEET"].median()
df["GROSS SQUARE FEET"].median()
# Out:
# 2000.0

# %%
df.isnull().sum()
# Out:
# BOROUGH                               0
# NEIGHBORHOOD                          0
# BUILDING CLASS CATEGORY               0
# TAX CLASS AT PRESENT                673
# BLOCK                                 0
# LOT                                   0
# BUILDING CLASS AT PRESENT           673
# ADDRESS                               0
# APARTMENT NUMBER                  54166
# ZIP CODE                              0
# RESIDENTIAL UNITS                     0
# COMMERCIAL UNITS                      0
# TOTAL UNITS                           0
# LAND SQUARE FEET                      0
# GROSS SQUARE FEET                     0
# YEAR BUILT                            0
# TAX CLASS AT TIME OF SALE             0
# BUILDING CLASS AT TIME OF SALE        0
# SALE PRICE                            0
# SALE DATE                             0
# dtype: int64

# %%
df.head()
# Out:
#    BOROUGH   NEIGHBORHOOD                      BUILDING CLASS CATEGORY  \
# 0        1  ALPHABET CITY  07 RENTALS - WALKUP APARTMENTS
# 3        1  ALPHABET CITY  07 RENTALS - WALKUP APARTMENTS
# 4        1  ALPHABET CITY  07 RENTALS - WALKUP APARTMENTS
# 6        1  ALPHABET CITY  07 RENTALS - WALKUP APARTMENTS
# 9        1  ALPHABET CITY  08 RENTALS - ELEVATOR APARTMENTS
#
#   TAX CLASS AT PRESENT  BLOCK  LOT BUILDING CLASS AT PRESENT  \
# 0                   2A    392    6                        C2
# 3                   2B    402   21                        C4
# 4                   2A    404   55                        C2
# 6                   2B    406   32                        C4
# 9                    2    387  153                        D9
#
#                   ADDRESS APARTMENT NUMBER  ZIP CODE  RESIDENTIAL UNITS  \
# 0            153 AVENUE B              NaN     10009                  5
# 3     154 EAST 7TH STREET              NaN     10009                 10
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 69607 entries, 0 to 84547
# Data columns (total 20 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   BOROUGH                         69607 non-null  int64
#  1   NEIGHBORHOOD                    69607 non-null  object
#  2   BUILDING CLASS CATEGORY         69607 non-null  object
#  3   TAX CLASS AT PRESENT            68934 non-null  object
#  4   BLOCK                           69607 non-null  int64
#  5   LOT                             69607 non-null  int64
#  6   BUILDING CLASS AT PRESENT       68934 non-null  object
#  7   ADDRESS                         69607 non-null  object
#  8   APARTMENT NUMBER                15441 non-null  object
#  9   ZIP CODE                        69607 non-null  int64
#  10  RESIDENTIAL UNITS               69607 non-null  int64
#  11  COMMERCIAL UNITS                69607 non-null  int64
# ...

# %% [markdown]
# DROPPING UNNECESSARY COLUMN:

# %%
df = df.drop(columns = 'APARTMENT NUMBER')

# %% [markdown]
# CLEANED ALL NULLS AND ONLY FEW LEFT IN 2 COLUMNS WHICH WONT AFFECT OUR ANALYSIS:

# %%
df.isnull().sum()
# Out:
# BOROUGH                             0
# NEIGHBORHOOD                        0
# BUILDING CLASS CATEGORY             0
# TAX CLASS AT PRESENT              673
# BLOCK                               0
# LOT                                 0
# BUILDING CLASS AT PRESENT         673
# ADDRESS                             0
# ZIP CODE                            0
# RESIDENTIAL UNITS                   0
# COMMERCIAL UNITS                    0
# TOTAL UNITS                         0
# LAND SQUARE FEET                    0
# GROSS SQUARE FEET                   0
# YEAR BUILT                          0
# TAX CLASS AT TIME OF SALE           0
# BUILDING CLASS AT TIME OF SALE      0
# SALE PRICE                          0
# SALE DATE                           0
# dtype: int64

# %%
df.head()
# Out:
#    BOROUGH   NEIGHBORHOOD                      BUILDING CLASS CATEGORY  \
# 0        1  ALPHABET CITY  07 RENTALS - WALKUP APARTMENTS
# 3        1  ALPHABET CITY  07 RENTALS - WALKUP APARTMENTS
# 4        1  ALPHABET CITY  07 RENTALS - WALKUP APARTMENTS
# 6        1  ALPHABET CITY  07 RENTALS - WALKUP APARTMENTS
# 9        1  ALPHABET CITY  08 RENTALS - ELEVATOR APARTMENTS
#
#   TAX CLASS AT PRESENT  BLOCK  LOT BUILDING CLASS AT PRESENT  \
# 0                   2A    392    6                        C2
# 3                   2B    402   21                        C4
# 4                   2A    404   55                        C2
# 6                   2B    406   32                        C4
# 9                    2    387  153                        D9
#
#                   ADDRESS  ZIP CODE  RESIDENTIAL UNITS  COMMERCIAL UNITS  \
# 0            153 AVENUE B     10009                  5                 0
# 3     154 EAST 7TH STREET     10009                 10                 0
# ...

# %% [markdown]
# SPLITTING SALE DATE COLUMN TO 2 COLUMNS OF SALE YEAR AND SALE MONTH:

# %%
df['SALE DATE'] = pd.to_datetime(df['SALE DATE'])

# %%
df['Sale Year'] = df['SALE DATE'].dt.year

# %%
df['Sale Month'] = df['SALE DATE'].dt.month

# %%
df.head()
# Out:
#    BOROUGH   NEIGHBORHOOD                      BUILDING CLASS CATEGORY  \
# 0        1  ALPHABET CITY  07 RENTALS - WALKUP APARTMENTS
# 3        1  ALPHABET CITY  07 RENTALS - WALKUP APARTMENTS
# 4        1  ALPHABET CITY  07 RENTALS - WALKUP APARTMENTS
# 6        1  ALPHABET CITY  07 RENTALS - WALKUP APARTMENTS
# 9        1  ALPHABET CITY  08 RENTALS - ELEVATOR APARTMENTS
#
#   TAX CLASS AT PRESENT  BLOCK  LOT BUILDING CLASS AT PRESENT  \
# 0                   2A    392    6                        C2
# 3                   2B    402   21                        C4
# 4                   2A    404   55                        C2
# 6                   2B    406   32                        C4
# 9                    2    387  153                        D9
#
#                   ADDRESS  ZIP CODE  RESIDENTIAL UNITS  ...  TOTAL UNITS  \
# 0            153 AVENUE B     10009                  5  ...            5
# 3     154 EAST 7TH STREET     10009                 10  ...           10
# ...

# %% [markdown]
# EXPORTING CLEANED CSV:

# %%
df.to_csv("Cleaned_NYC_PropertySales_Data", index = None)

# %% [markdown]
# # DATA ANALYTICS AND VISUALIZATIONS:

# %%
df1 = df[(df['SALE PRICE'] == 0) | (df['SALE PRICE'] > 50000)]
df1.shape
# Out:
# (67687, 21)

# %% [markdown]
# TO CHECK OUTLIERS IN PRICE COLUMN:

# %%
sns.boxplot(y = df['SALE PRICE'])
# Out:
# <Axes: ylabel='SALE PRICE'>

# %% [markdown]
# REMOVING OUTLIERS IN SALE PRICE COLUMN USING IQR METHOD:

# %%
q1 = df['SALE PRICE'].quantile(0.25)
q1
# Out:
# 230000.0

# %%
q3 = df['SALE PRICE'].quantile(0.75)
q3
# Out:
# 950000.0

# %%
iqr = q3-q1
iqr
# Out:
# 720000.0

# %%
upper_bound = q3+1.5*iqr
upper_bound
# Out:
# 2030000.0

# %%
lower_bound = q1-1.5*iqr
lower_bound
# Out:
# -850000.0

# %%
df[df['SALE PRICE'] < 0]
# Out:
# Empty DataFrame
# Columns: [BOROUGH, NEIGHBORHOOD, BUILDING CLASS CATEGORY, TAX CLASS AT PRESENT, BLOCK, LOT, BUILDING CLASS AT PRESENT, ADDRESS, ZIP CODE, RESIDENTIAL UNITS, COMMERCIAL UNITS, TOTAL UNITS, LAND SQUARE FEET, GROSS SQUARE FEET, YEAR BUILT, TAX CLASS AT TIME OF SALE, BUILDING CLASS AT TIME OF SALE, SALE PRICE, SALE DATE, Sale Year, Sale Month]
# Index: []
#
# [0 rows x 21 columns]

# %%
df_outliers = df[(df['SALE PRICE'] < lower_bound) | (df['SALE PRICE'] > upper_bound)]
df_outliers.shape
df_outliers
# Out:
#        BOROUGH       NEIGHBORHOOD  \
# 0            1      ALPHABET CITY
# 3            1      ALPHABET CITY
# 4            1      ALPHABET CITY
# 6            1      ALPHABET CITY
# 9            1      ALPHABET CITY
# ...        ...                ...
# 83878        5  WEST NEW BRIGHTON
# 83879        5  WEST NEW BRIGHTON
# 83911        5  WEST NEW BRIGHTON
# 84392        5        WILLOWBROOK
# 84546        5            WOODROW
#
#                            BUILDING CLASS CATEGORY TAX CLASS AT PRESENT  \
# 0      07 RENTALS - WALKUP APARTMENTS                                2A
# 3      07 RENTALS - WALKUP APARTMENTS                                2B
# 4      07 RENTALS - WALKUP APARTMENTS                                2A
# 6      07 RENTALS - WALKUP APARTMENTS                                2B
# 9      08 RENTALS - ELEVATOR APARTMENTS                               2
# ...                                            ...                  ...
# ...

# %%
df_without_outliers = df[(df['SALE PRICE'] > lower_bound) & (df['SALE PRICE'] < upper_bound)]
df_without_outliers
# Out:
#        BOROUGH   NEIGHBORHOOD                      BUILDING CLASS CATEGORY  \
# 12           1  ALPHABET CITY  09 COOPS - WALKUP APARTMENTS
# 13           1  ALPHABET CITY  09 COOPS - WALKUP APARTMENTS
# 14           1  ALPHABET CITY  09 COOPS - WALKUP APARTMENTS
# 15           1  ALPHABET CITY  09 COOPS - WALKUP APARTMENTS
# 16           1  ALPHABET CITY  09 COOPS - WALKUP APARTMENTS
# ...        ...            ...                                          ...
# 84541        5        WOODROW  02 TWO FAMILY DWELLINGS
# 84543        5        WOODROW  02 TWO FAMILY DWELLINGS
# 84544        5        WOODROW  02 TWO FAMILY DWELLINGS
# 84545        5        WOODROW  02 TWO FAMILY DWELLINGS
# 84547        5        WOODROW  35 INDOOR PUBLIC AND CULTURAL FACILITIES
#
#       TAX CLASS AT PRESENT  BLOCK  LOT BUILDING CLASS AT PRESENT  \
# 12                       2    373   40                        C6
# 13                       2    373   40                        C6
# ...

# %% [markdown]
# PLOTTING BOXPLOT FOR FINDING IF WE REMOVED OUTLIERS:

# %%
sns.boxplot(y = df_without_outliers["SALE PRICE"])
# Out:
# <Axes: ylabel='SALE PRICE'>

# %% [markdown]
# IN ABOVE PLOT WE CAN SEE THAT WE STILL HAVE A LOT OF UPPER OUTLIERS BUT THOSE CAN BE EXCEPTIONALLY EXPENSIVE PROPERTIES FOR SALE TOO.

# %%
df.columns
# Out:
# Index(['BOROUGH', 'NEIGHBORHOOD', 'BUILDING CLASS CATEGORY',
#        'TAX CLASS AT PRESENT', 'BLOCK', 'LOT', 'BUILDING CLASS AT PRESENT',
#        'ADDRESS', 'ZIP CODE', 'RESIDENTIAL UNITS', 'COMMERCIAL UNITS',
#        'TOTAL UNITS', 'LAND SQUARE FEET', 'GROSS SQUARE FEET', 'YEAR BUILT',
#        'TAX CLASS AT TIME OF SALE', 'BUILDING CLASS AT TIME OF SALE',
#        'SALE PRICE', 'SALE DATE', 'Sale Year', 'Sale Month'],
#       dtype='object')

# %%
df_without_outliers.groupby('Sale Year')['SALE PRICE'].mean()
# Out:
# Sale Year
# 2016   516,230.64
# 2017   563,232.13
# Name: SALE PRICE, dtype: float64

# %%
df_without_outliers.groupby('Sale Month')['SALE PRICE'].mean().plot()
# Out:
# <Axes: xlabel='Sale Month'>

# %%
df_without_outliers.groupby('Sale Year')['SALE PRICE'].sum()
# Out:
# Sale Year
# 2016   11,286,350,410.00
# 2017   23,137,575,758.00
# Name: SALE PRICE, dtype: float64

# %%
df_without_outliers.groupby('BOROUGH')['SALE PRICE'].mean().plot(kind = 'bar')
# Out:
# <Axes: xlabel='BOROUGH'>

# %%
df_without_outliers.groupby('NEIGHBORHOOD')['SALE PRICE'].mean().sort_values()
# Out:
# NEIGHBORHOOD
# PELHAM BAY                        10.00
# CO-OP CITY                   116,000.00
# PARKCHESTER                  144,499.09
# VAN CORTLANDT PARK           162,450.00
# KINGSBRIDGE HTS/UNIV HTS     188,664.64
#                                ...
# ROSSVILLE-PORT MOBIL       1,125,000.00
# FINANCIAL                  1,125,138.80
# CIVIC CENTER               1,144,513.41
# FLATIRON                   1,154,194.75
# LITTLE ITALY               1,367,600.00
# Name: SALE PRICE, Length: 253, dtype: float64

# %%
df_without_outliers['NEIGHBORHOOD'].unique()
# Out:
# array(['ALPHABET CITY', 'CHELSEA', 'CHINATOWN', 'CIVIC CENTER', 'CLINTON',
#        'EAST VILLAGE', 'FASHION', 'FINANCIAL', 'FLATIRON', 'GRAMERCY',
#        'GREENWICH VILLAGE-CENTRAL', 'GREENWICH VILLAGE-WEST',
#        'HARLEM-CENTRAL', 'HARLEM-EAST', 'HARLEM-UPPER', 'HARLEM-WEST',
#        'INWOOD', 'JAVITS CENTER', 'KIPS BAY', 'LITTLE ITALY',
#        'LOWER EAST SIDE', 'MANHATTAN VALLEY', 'MIDTOWN CBD',
#        'MIDTOWN EAST', 'MIDTOWN WEST', 'MORNINGSIDE HEIGHTS',
#        'MURRAY HILL', 'ROOSEVELT ISLAND', 'SOHO', 'SOUTHBRIDGE',
#        'TRIBECA', 'UPPER EAST SIDE (59-79)', 'UPPER EAST SIDE (79-96)',
#        'UPPER EAST SIDE (96-110)', 'UPPER WEST SIDE (59-79)',
#        'UPPER WEST SIDE (79-96)', 'UPPER WEST SIDE (96-116)',
#        'WASHINGTON HEIGHTS LOWER', 'WASHINGTON HEIGHTS UPPER', 'BATHGATE',
#        'BAYCHESTER', 'BEDFORD PARK/NORWOOD', 'BELMONT', 'BRONX PARK',
#        'BRONXDALE', 'CASTLE HILL/UNIONPORT', 'CITY ISLAND',
# ...

# %%
len(df_without_outliers[df_without_outliers['SALE PRICE'] == 0])
# Out:
# 10012

# %%
df_without_outliers.groupby('YEAR BUILT')['SALE PRICE'].mean().sort_values()
# Out:
# YEAR BUILT
# 1871           0.00
# 1829           0.00
# 1852           0.00
# 1840           0.00
# 1847           0.00
# 1895      33,333.33
# 2017     217,500.00
# 1952     274,187.20
# 1953     280,227.12
# 1954     307,568.56
# 1951     333,400.07
# 1949     358,944.56
# 1948     359,172.84
# 1865     370,500.00
# 1958     396,597.52
# 1947     399,044.09
# 1933     408,372.78
# 1995     416,575.78
# 1990     422,082.61
# 1943     426,240.67
# 1942     438,113.37
# 1992     438,204.81
# 1994     441,719.65
# 1937     445,670.14
# 2000     451,343.92
# 1988     454,386.73
# 1956     461,628.03
# 1939     461,721.51
# 1932     461,810.10
# 1957     464,924.62
# 2011     467,480.78
# 1999     468,094.14
# 1981     469,998.98
# 1993     472,424.48
# 1941     472,694.13
# 1963     475,318.80
# 1964     476,499.15
# 1969     478,279.23
# 1997     481,184.27
# 1966     487,716.76
# 2001     492,961.55
# 1882     493,000.00
# 1950     494,701.48
# 1936     498,958.28
# ...

# %%
df_without_outliers[df_without_outliers['YEAR BUILT']==0]
# Out:
#        BOROUGH   NEIGHBORHOOD                      BUILDING CLASS CATEGORY  \
# 76           1  ALPHABET CITY  12 CONDOS - WALKUP APARTMENTS
# 87           1  ALPHABET CITY  13 CONDOS - ELEVATOR APARTMENTS
# 117          1  ALPHABET CITY  13 CONDOS - ELEVATOR APARTMENTS
# 118          1  ALPHABET CITY  13 CONDOS - ELEVATOR APARTMENTS
# 130          1  ALPHABET CITY  13 CONDOS - ELEVATOR APARTMENTS
# ...        ...            ...                                          ...
# 84162        5    WESTERLEIGH  05 TAX CLASS 1 VACANT LAND
# 84163        5    WESTERLEIGH  05 TAX CLASS 1 VACANT LAND
# 84166        5    WESTERLEIGH  05 TAX CLASS 1 VACANT LAND
# 84167        5    WESTERLEIGH  05 TAX CLASS 1 VACANT LAND
# 84389        5    WILLOWBROOK  05 TAX CLASS 1 VACANT LAND
#
#       TAX CLASS AT PRESENT  BLOCK   LOT BUILDING CLASS AT PRESENT  \
# 76                       2    386  1002                        R2
# 87                       2    375  1004                        R4
# ...

# %%
df_without_outliers.groupby('RESIDENTIAL UNITS')['SALE PRICE'].mean().sort_values()
# Out:
# RESIDENTIAL UNITS
# 59             0.00
# 34             0.00
# 35             0.00
# 37             0.00
# 38             0.00
# 40             0.00
# 41             0.00
# 44             0.00
# 46             0.00
# 146            0.00
# 50             0.00
# 51             0.00
# 52             0.00
# 54             0.00
# 889            0.00
# 61             0.00
# 63             0.00
# 65             0.00
# 73             0.00
# 74             0.00
# 81             0.00
# 83             0.00
# 90             0.00
# 91             0.00
# 113            0.00
# 114            0.00
# 127            0.00
# 130            0.00
# 33             0.00
# 31             0.00
# 45             0.00
# 29             0.00
# 716            0.00
# 680            0.00
# 271            0.00
# 180            0.00
# 17             0.00
# 18             0.00
# 165            0.00
# 21             0.00
# 139            0.00
# 23             0.00
# 164            0.00
# 56             0.33
# ...

# %%
df_without_outliers.columns
# Out:
# Index(['BOROUGH', 'NEIGHBORHOOD', 'BUILDING CLASS CATEGORY',
#        'TAX CLASS AT PRESENT', 'BLOCK', 'LOT', 'BUILDING CLASS AT PRESENT',
#        'ADDRESS', 'ZIP CODE', 'RESIDENTIAL UNITS', 'COMMERCIAL UNITS',
#        'TOTAL UNITS', 'LAND SQUARE FEET', 'GROSS SQUARE FEET', 'YEAR BUILT',
#        'TAX CLASS AT TIME OF SALE', 'BUILDING CLASS AT TIME OF SALE',
#        'SALE PRICE', 'SALE DATE', 'Sale Year', 'Sale Month'],
#       dtype='object')

# %%
df_without_outliers['TAX CLASS AT TIME OF SALE'].unique()
# Out:
# array([2, 1, 4, 3])

# %%
df_without_outliers.groupby('TAX CLASS AT TIME OF SALE')['SALE PRICE'].sum().plot(kind = 'bar')
# Out:
# <Axes: xlabel='TAX CLASS AT TIME OF SALE'>

# %%
df_without_outliers[df_without_outliers['BOROUGH']==1].groupby('NEIGHBORHOOD')['SALE PRICE'].mean().sort_values().plot(kind = 'bar')
# Out:
# <Axes: xlabel='NEIGHBORHOOD'>

# %%
df_without_outliers.groupby(['BOROUGH','Sale Year'])['SALE PRICE'].mean().plot(kind = 'bar', stacked = True)
# Out:
# <Axes: xlabel='BOROUGH,Sale Year'>

# %%
df_without_outliers.groupby(['Sale Month','BOROUGH'])['SALE PRICE'].mean()
# Out:
# Sale Month  BOROUGH
# 1           1         910,280.55
#             2         272,901.04
#             3         489,391.63
#             4         545,184.52
#             5         461,525.99
# 2           1         886,421.71
#             2         287,533.37
#             3         447,886.58
#             4         524,552.22
#             5         455,095.75
# 3           1         877,504.24
#             2         307,359.16
#             3         459,380.46
#             4         540,432.40
#             5         468,424.98
# 4           1         897,169.72
#             2         296,163.84
#             3         473,381.97
#             4         536,541.12
#             5         471,109.51
# 5           1         949,281.96
#             2         308,830.05
#             3         478,408.14
#             4         561,154.24
#             5         486,622.99
# 6           1         938,415.18
#             2         292,351.40
# ...

# %%
df_without_outliers.groupby(['BUILDING CLASS CATEGORY'])['SALE PRICE'].mean().sort_values().plot(kind = 'bar', figsize = (9,6))
# Out:
# <Axes: xlabel='BUILDING CLASS CATEGORY'>

# %%
upper_bound
# Out:
# 2030000.0

# %%
df['SALE PRICE'].sort_values(ascending = False)
# Out:
# 7447    2,210,000,000.00
# 2559    1,040,000,000.00
# 2557      652,000,000.00
# 6332      620,000,000.00
# 2050      565,000,000.00
#               ...
# 22717               0.00
# 22718               0.00
# 40895               0.00
# 22723               0.00
# 23326               0.00
# Name: SALE PRICE, Length: 69607, dtype: float64

# %%
df[df['SALE PRICE'] > upper_bound].count()
# Out:
# BOROUGH                           6663
# NEIGHBORHOOD                      6663
# BUILDING CLASS CATEGORY           6663
# TAX CLASS AT PRESENT              6489
# BLOCK                             6663
# LOT                               6663
# BUILDING CLASS AT PRESENT         6489
# ADDRESS                           6663
# ZIP CODE                          6663
# RESIDENTIAL UNITS                 6663
# COMMERCIAL UNITS                  6663
# TOTAL UNITS                       6663
# LAND SQUARE FEET                  6663
# GROSS SQUARE FEET                 6663
# YEAR BUILT                        6663
# TAX CLASS AT TIME OF SALE         6663
# BUILDING CLASS AT TIME OF SALE    6663
# SALE PRICE                        6663
# SALE DATE                         6663
# Sale Year                         6663
# Sale Month                        6663
# dtype: int64

# %%
df_premium = df[df['SALE PRICE'] > upper_bound]
df_premium
# Out:
#        BOROUGH       NEIGHBORHOOD  \
# 0            1      ALPHABET CITY
# 3            1      ALPHABET CITY
# 4            1      ALPHABET CITY
# 6            1      ALPHABET CITY
# 9            1      ALPHABET CITY
# ...        ...                ...
# 83878        5  WEST NEW BRIGHTON
# 83879        5  WEST NEW BRIGHTON
# 83911        5  WEST NEW BRIGHTON
# 84392        5        WILLOWBROOK
# 84546        5            WOODROW
#
#                            BUILDING CLASS CATEGORY TAX CLASS AT PRESENT  \
# 0      07 RENTALS - WALKUP APARTMENTS                                2A
# 3      07 RENTALS - WALKUP APARTMENTS                                2B
# 4      07 RENTALS - WALKUP APARTMENTS                                2A
# 6      07 RENTALS - WALKUP APARTMENTS                                2B
# 9      08 RENTALS - ELEVATOR APARTMENTS                               2
# ...                                            ...                  ...
# ...

# %%
df_premium.plot(kind='scatter', x='GROSS SQUARE FEET', y='SALE PRICE', figsize=(10, 6), color='blue')
# Out:
# <Axes: xlabel='GROSS SQUARE FEET', ylabel='SALE PRICE'>

# %%
df.columns
# Out:
# Index(['BOROUGH', 'NEIGHBORHOOD', 'BUILDING CLASS CATEGORY',
#        'TAX CLASS AT PRESENT', 'BLOCK', 'LOT', 'BUILDING CLASS AT PRESENT',
#        'ADDRESS', 'ZIP CODE', 'RESIDENTIAL UNITS', 'COMMERCIAL UNITS',
#        'TOTAL UNITS', 'LAND SQUARE FEET', 'GROSS SQUARE FEET', 'YEAR BUILT',
#        'TAX CLASS AT TIME OF SALE', 'BUILDING CLASS AT TIME OF SALE',
#        'SALE PRICE', 'SALE DATE', 'Sale Year', 'Sale Month'],
#       dtype='object')

# %%
corr_matrix = df_premium.select_dtypes(include = ['number']).corr()
corr_matrix
# Out:
#                            BOROUGH  BLOCK   LOT  ZIP CODE  RESIDENTIAL UNITS  \
# BOROUGH                       1.00   0.46 -0.32      0.31               0.02
# BLOCK                         0.46   1.00 -0.28      0.16               0.07
# LOT                          -0.32  -0.28  1.00     -0.25              -0.11
# ZIP CODE                      0.31   0.16 -0.25      1.00               0.03
# RESIDENTIAL UNITS             0.02   0.07 -0.11      0.03               1.00
# COMMERCIAL UNITS              0.05   0.02 -0.06      0.02               0.03
# TOTAL UNITS                   0.03   0.07 -0.12      0.03               0.97
# LAND SQUARE FEET              0.13   0.06 -0.04     -0.04               0.09
# GROSS SQUARE FEET             0.05   0.06 -0.12      0.03               0.55
# YEAR BUILT                    0.09   0.04 -0.21      0.40               0.05
# TAX CLASS AT TIME OF SALE     0.15   0.18 -0.07      0.01              -0.02
# ...

# %%
plt.figure(figsize=(15, 6))
sns.heatmap(corr_matrix, annot = True)
# Out:
# <Axes: >

# %%
df_premium.sort_values(by = ['SALE PRICE'], ascending = False).head()  # top 5 most high priced properties sold in nyc
# Out:
#       BOROUGH NEIGHBORHOOD                      BUILDING CLASS CATEGORY  \
# 7447        1  MIDTOWN CBD  21 OFFICE BUILDINGS
# 2559        1    FINANCIAL  21 OFFICE BUILDINGS
# 2557        1    FINANCIAL  21 OFFICE BUILDINGS
# 6332        1     KIPS BAY  08 RENTALS - ELEVATOR APARTMENTS
# 2050        1      FASHION  21 OFFICE BUILDINGS
#
#      TAX CLASS AT PRESENT  BLOCK  LOT BUILDING CLASS AT PRESENT  \
# 7447                    4   1301    1                        O4
# 2559                    4     40    3                        O4
# 2557                    4     29    1                        O4
# 6332                    2    934    1                        D6
# 2050                    4    833   11                        O4
#
#                  ADDRESS  ZIP CODE  RESIDENTIAL UNITS  ...  TOTAL UNITS  \
# 7447     245 PARK AVENUE     10167                  0  ...           35
# 2559      60 WALL STREET     10005                  0  ...            1
# ...

# %%
df_premium[df_premium['Sale Year'] == 2016].sort_values(by = ['SALE PRICE'], ascending = False).head()  # top 5 most high priced properties sold in nyc in 2016
# Out:
#        BOROUGH           NEIGHBORHOOD  \
# 6332         1               KIPS BAY
# 2050         1                FASHION
# 35389        3  DOWNTOWN-FULTON FERRY
# 6317         1          JAVITS CENTER
# 66508        4       LONG ISLAND CITY
#
#                            BUILDING CLASS CATEGORY TAX CLASS AT PRESENT  \
# 6332   08 RENTALS - ELEVATOR APARTMENTS                               2
# 2050   21 OFFICE BUILDINGS                                            4
# 35389  29 COMMERCIAL GARAGES                                          4
# 6317   21 OFFICE BUILDINGS                                            4
# 66508  27 FACTORIES                                                   4
#
#        BLOCK  LOT BUILDING CLASS AT PRESENT               ADDRESS  ZIP CODE  \
# 6332     934    1                        D6    460-520 2ND AVENUE     10016
# 2050     833   11                        O4         1250 BROADWAY     10001
# ...

# %%
df_premium.columns
# Out:
# Index(['BOROUGH', 'NEIGHBORHOOD', 'BUILDING CLASS CATEGORY',
#        'TAX CLASS AT PRESENT', 'BLOCK', 'LOT', 'BUILDING CLASS AT PRESENT',
#        'ADDRESS', 'ZIP CODE', 'RESIDENTIAL UNITS', 'COMMERCIAL UNITS',
#        'TOTAL UNITS', 'LAND SQUARE FEET', 'GROSS SQUARE FEET', 'YEAR BUILT',
#        'TAX CLASS AT TIME OF SALE', 'BUILDING CLASS AT TIME OF SALE',
#        'SALE PRICE', 'SALE DATE', 'Sale Year', 'Sale Month'],
#       dtype='object')

# %%
df_premium[(df_premium['TOTAL UNITS'] == 1)].sort_values(by = 'SALE PRICE', ascending = False)
# Out:
#        BOROUGH             NEIGHBORHOOD  \
# 2559         1                FINANCIAL
# 2557         1                FINANCIAL
# 8723         1             MIDTOWN EAST
# 7446         1              MIDTOWN CBD
# 16412        1  UPPER WEST SIDE (59-79)
# ...        ...                      ...
# 48454        3       WILLIAMSBURG-NORTH
# 6518         1                 KIPS BAY
# 8601         1             MIDTOWN EAST
# 28837        3              BOERUM HILL
# 2426         1                FINANCIAL
#
#                            BUILDING CLASS CATEGORY TAX CLASS AT PRESENT  \
# 2559   21 OFFICE BUILDINGS                                            4
# 2557   21 OFFICE BUILDINGS                                            4
# 8723   43 CONDO OFFICE BUILDINGS                                      4
# 7446   21 OFFICE BUILDINGS                                            4
# 16412  26 OTHER HOTELS                                                4
# ...

# %%
df_without_outliers[df_without_outliers['TOTAL UNITS'] == 1].sort_values(by = 'SALE PRICE', ascending = False)
# Out:
#        BOROUGH             NEIGHBORHOOD  \
# 35573        3     DOWNTOWN-FULTON MALL
# 10756        1                     SOHO
# 2433         1                FINANCIAL
# 16174        1  UPPER WEST SIDE (59-79)
# 48189        3        WILLIAMSBURG-EAST
# ...        ...                      ...
# 48614        3       WILLIAMSBURG-NORTH
# 48616        3       WILLIAMSBURG-NORTH
# 29646        3             BOROUGH PARK
# 48618        3       WILLIAMSBURG-NORTH
# 29608        3             BOROUGH PARK
#
#                            BUILDING CLASS CATEGORY TAX CLASS AT PRESENT  \
# 35573  13 CONDOS - ELEVATOR APARTMENTS                                2
# 10756  13 CONDOS - ELEVATOR APARTMENTS                                2
# 2433   13 CONDOS - ELEVATOR APARTMENTS                                2
# 16174  13 CONDOS - ELEVATOR APARTMENTS                                2
# 48189  22 STORE BUILDINGS                                             4
# ...

# %%
df_premium.sort_values(by = 'SALE PRICE', ascending = False).head()
# Out:
#       BOROUGH NEIGHBORHOOD                      BUILDING CLASS CATEGORY  \
# 7447        1  MIDTOWN CBD  21 OFFICE BUILDINGS
# 2559        1    FINANCIAL  21 OFFICE BUILDINGS
# 2557        1    FINANCIAL  21 OFFICE BUILDINGS
# 6332        1     KIPS BAY  08 RENTALS - ELEVATOR APARTMENTS
# 2050        1      FASHION  21 OFFICE BUILDINGS
#
#      TAX CLASS AT PRESENT  BLOCK  LOT BUILDING CLASS AT PRESENT  \
# 7447                    4   1301    1                        O4
# 2559                    4     40    3                        O4
# 2557                    4     29    1                        O4
# 6332                    2    934    1                        D6
# 2050                    4    833   11                        O4
#
#                  ADDRESS  ZIP CODE  RESIDENTIAL UNITS  ...  TOTAL UNITS  \
# 7447     245 PARK AVENUE     10167                  0  ...           35
# 2559      60 WALL STREET     10005                  0  ...            1
# ...

# %%
df_without_outliers.sort_values(by = 'SALE PRICE', ascending = False).head()
# Out:
#        BOROUGH             NEIGHBORHOOD  \
# 35573        3     DOWNTOWN-FULTON MALL
# 5252         1           HARLEM-CENTRAL
# 13802        1  UPPER EAST SIDE (79-96)
# 48189        3        WILLIAMSBURG-EAST
# 48190        3        WILLIAMSBURG-EAST
#
#                            BUILDING CLASS CATEGORY TAX CLASS AT PRESENT  \
# 35573  13 CONDOS - ELEVATOR APARTMENTS                                2
# 5252   13 CONDOS - ELEVATOR APARTMENTS                              NaN
# 13802  10 COOPS - ELEVATOR APARTMENTS                                 2
# 48189  22 STORE BUILDINGS                                             4
# 48190  22 STORE BUILDINGS                                             4
#
#        BLOCK   LOT BUILDING CLASS AT PRESENT                    ADDRESS  \
# 35573    170  1069                        R4           265 STATE STREET
# 5252    1826  1219                       NaN  2040 FREDERICK DOUGLASS B
# ...

# %%
df_without_outliers[df_without_outliers['SALE PRICE'] == 0]
# Out:
#        BOROUGH     NEIGHBORHOOD                      BUILDING CLASS CATEGORY  \
# 18311        2         BATHGATE  01 ONE FAMILY DWELLINGS
# 18313        2         BATHGATE  01 ONE FAMILY DWELLINGS
# 18314        2         BATHGATE  02 TWO FAMILY DWELLINGS
# 18315        2         BATHGATE  02 TWO FAMILY DWELLINGS
# 18320        2         BATHGATE  02 TWO FAMILY DWELLINGS
# ...        ...              ...                                          ...
# 49391        3  WYCKOFF HEIGHTS  27 FACTORIES
# 49396        3  WYCKOFF HEIGHTS  31 COMMERCIAL VACANT LAND
# 49398        3  WYCKOFF HEIGHTS  41 TAX CLASS 4 - OTHER
# 49399        3  WYCKOFF HEIGHTS  41 TAX CLASS 4 - OTHER
# 49401        3  WYCKOFF HEIGHTS  44 CONDO PARKING
#
#       TAX CLASS AT PRESENT  BLOCK   LOT BUILDING CLASS AT PRESENT  \
# 18311                    1   3048    27                        A1
# 18313                    1   3053   105                        A1
# ...

# %%
df_transfer_owner = df_without_outliers[df_without_outliers['SALE PRICE'] == 0]
df_transfer_owner
# Out:
#        BOROUGH     NEIGHBORHOOD                      BUILDING CLASS CATEGORY  \
# 18311        2         BATHGATE  01 ONE FAMILY DWELLINGS
# 18313        2         BATHGATE  01 ONE FAMILY DWELLINGS
# 18314        2         BATHGATE  02 TWO FAMILY DWELLINGS
# 18315        2         BATHGATE  02 TWO FAMILY DWELLINGS
# 18320        2         BATHGATE  02 TWO FAMILY DWELLINGS
# ...        ...              ...                                          ...
# 49391        3  WYCKOFF HEIGHTS  27 FACTORIES
# 49396        3  WYCKOFF HEIGHTS  31 COMMERCIAL VACANT LAND
# 49398        3  WYCKOFF HEIGHTS  41 TAX CLASS 4 - OTHER
# 49399        3  WYCKOFF HEIGHTS  41 TAX CLASS 4 - OTHER
# 49401        3  WYCKOFF HEIGHTS  44 CONDO PARKING
#
#       TAX CLASS AT PRESENT  BLOCK   LOT BUILDING CLASS AT PRESENT  \
# 18311                    1   3048    27                        A1
# 18313                    1   3053   105                        A1
# ...

# %%
df_transfer_owner.columns
# Out:
# Index(['BOROUGH', 'NEIGHBORHOOD', 'BUILDING CLASS CATEGORY',
#        'TAX CLASS AT PRESENT', 'BLOCK', 'LOT', 'BUILDING CLASS AT PRESENT',
#        'ADDRESS', 'ZIP CODE', 'RESIDENTIAL UNITS', 'COMMERCIAL UNITS',
#        'TOTAL UNITS', 'LAND SQUARE FEET', 'GROSS SQUARE FEET', 'YEAR BUILT',
#        'TAX CLASS AT TIME OF SALE', 'BUILDING CLASS AT TIME OF SALE',
#        'SALE PRICE', 'SALE DATE', 'Sale Year', 'Sale Month'],
#       dtype='object')

# %% [markdown]
# TRANSFER SALES BUILDING CATEGORY WISE- TOP 10:

# %%
df_transfer_owner.groupby(['BUILDING CLASS AT TIME OF SALE'])['BUILDING CLASS AT TIME OF SALE'].count().sort_values(ascending = False).head(10).plot(kind = 'bar', figsize=(20,12))
# Out:
# <Axes: xlabel='BUILDING CLASS AT TIME OF SALE'>

# %%
df_without_outliers[df_without_outliers['BUILDING CLASS AT TIME OF SALE'].str.startswith('H')]
# Out:
#        BOROUGH               NEIGHBORHOOD  \
# 9609         1               MIDTOWN WEST
# 9610         1               MIDTOWN WEST
# 9611         1               MIDTOWN WEST
# 9612         1               MIDTOWN WEST
# 9613         1               MIDTOWN WEST
# 9614         1               MIDTOWN WEST
# 9615         1               MIDTOWN WEST
# 9617         1               MIDTOWN WEST
# 9622         1               MIDTOWN WEST
# 9628         1               MIDTOWN WEST
# 9630         1               MIDTOWN WEST
# 9631         1               MIDTOWN WEST
# 9634         1               MIDTOWN WEST
# 9635         1               MIDTOWN WEST
# 9636         1               MIDTOWN WEST
# 9638         1               MIDTOWN WEST
# 9650         1               MIDTOWN WEST
# 9651         1               MIDTOWN WEST
# 9662         1               MIDTOWN WEST
# 9664         1               MIDTOWN WEST
# 9665         1               MIDTOWN WEST
# ...

# %% [markdown]
# PREMIUM TOP 10 PROPERTIES SOLD BUILDING CLASS:

# %%
df_premium.groupby(['BUILDING CLASS AT TIME OF SALE'])['BUILDING CLASS AT TIME OF SALE'].count().sort_values(ascending = False).head(10).plot(kind = 'bar', figsize = (20,15))
# Out:
# <Axes: xlabel='BUILDING CLASS AT TIME OF SALE'>
